# %%
import pandas as pd
import requests
import pprint
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# # Google Public Service API

# %%
API_KEY = 'AIzaSyAqPyqmQmchj_kYw7KwDZFz9tCvBkshtjE'

new_york_reps = 'https://civicinfo.googleapis.com/civicinfo/v2/representatives/ocd-division%2Fcountry%3Aus%2Fstate%3Any?recursive=true&key=AIzaSyDqfPE99DZFTKO2bHaPAswJL7qyoKQQDFE'

# %%
the_results = requests.get(new_york_reps).json()

# %%
the_results
# Out:
# {'offices': [{'name': 'U.S. Senator',
#    'divisionId': 'ocd-division/country:us/state:ny',
#    'levels': ['country'],
#    'roles': ['legislatorUpperBody'],
#    'officialIndices': [0, 1]},
#   {'name': 'U.S. Representative',
#    'divisionId': 'ocd-division/country:us/state:ny/cd:7',
#    'levels': ['country'],
#    'roles': ['legislatorLowerBody'],
#    'officialIndices': [2]},
#   {'name': 'U.S. Representative',
#    'divisionId': 'ocd-division/country:us/state:ny/cd:6',
#    'levels': ['country'],
#    'roles': ['legislatorLowerBody'],
#    'officialIndices': [3]},
#   {'name': 'U.S. Representative',
#    'divisionId': 'ocd-division/country:us/state:ny/cd:9',
#    'levels': ['country'],
#    'roles': ['legislatorLowerBody'],
#    'officialIndices': [4]},
#   {'name': 'U.S. Representative',
#    'divisionId': 'ocd-division/country:us/state:ny/cd:8',
#    'levels': ['country'],
#    'roles': ['legislatorLowerBody'],
#    'officialIndices': [5]},
# ...

# %%
the_office = the_results['offices']

# %%
the_officials = the_results['officials']

# %%
the_divisions = the_results['divisions']

# %%
office_df = pd.DataFrame(the_office)

# %%
office_df
# Out:
#                                    name  \
# 0                          U.S. Senator
# 1                   U.S. Representative
# 2                   U.S. Representative
# 3                   U.S. Representative
# 4                   U.S. Representative
# ...                                 ...
# 1491  Albany City Common Council Member
# 1492  Albany City Common Council Member
# 1493  Albany City Common Council Member
# 1494  Albany City Common Council Member
# 1495  Albany City Common Council Member
#
#                                              divisionId      levels  \
# 0                      ocd-division/country:us/state:ny   [country]
# 1                 ocd-division/country:us/state:ny/cd:7   [country]
# 2                 ocd-division/country:us/state:ny/cd:6   [country]
# 3                 ocd-division/country:us/state:ny/cd:9   [country]
# 4                 ocd-division/country:us/state:ny/cd:8   [country]
# ...

# %%
office_df['officialIndices'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1496 entries, 0 to 1495
# Series name: officialIndices
# Non-Null Count  Dtype
# --------------  -----
# 1496 non-null   object
# dtypes: object(1)
# memory usage: 11.8+ KB

# %% [markdown]
# Explode elements in the 'officialIndices' column to expand multi list elements

# %%
new_office_df = office_df.explode('officialIndices')

# %% [markdown]
# Concatenate the two DataFrames; nfor the Offices and the Officials

# %%
ojukwu = pd.concat([new_office_df,officials_df],axis=1)

# %% [markdown]
# Get the 'name' column (two column names match in this case :D) from the result of the Concatenated DataFrame as above.
# That Gives us the names of the officials with their respective positions

# %%
ojukwu['name']
# Out:
#                                    name                   name
# 0                          U.S. Senator     Charles E. Schumer
# 1                          U.S. Senator  Kirsten E. Gillibrand
# 2                   U.S. Representative     Nydia M. Velázquez
# 3                   U.S. Representative             Grace Meng
# 4                   U.S. Representative       Yvette D. Clarke
# ...                                 ...                    ...
# 1661  Albany City Common Council Member         Ginnie Farrell
# 1662  Albany City Common Council Member         Thomas C. Hoey
# 1663  Albany City Common Council Member            Owusu Anane
# 1664  Albany City Common Council Member     Edward Hyde Clarke
# 1665  Albany City Common Council Member     Alfredo D. Balarin
#
# [1666 rows x 2 columns]

# %% [markdown]
# Reset the index of the Office Data frame to allow for concatenation with the officials Dataframe

# %%
new_office_df = new_office_df.reset_index(drop=True)

# %%
new_office_df.reset_index(drop=True)
# Out:
#                                    name  \
# 0                          U.S. Senator
# 1                          U.S. Senator
# 2                   U.S. Representative
# 3                   U.S. Representative
# 4                   U.S. Representative
# ...                                 ...
# 1661  Albany City Common Council Member
# 1662  Albany City Common Council Member
# 1663  Albany City Common Council Member
# 1664  Albany City Common Council Member
# 1665  Albany City Common Council Member
#
#                                              divisionId      levels  \
# 0                      ocd-division/country:us/state:ny   [country]
# 1                      ocd-division/country:us/state:ny   [country]
# 2                 ocd-division/country:us/state:ny/cd:7   [country]
# 3                 ocd-division/country:us/state:ny/cd:6   [country]
# 4                 ocd-division/country:us/state:ny/cd:9   [country]
# ...

# %% [markdown]
# Create a dataframe of the officials' data

# %%
officials_df = pd.DataFrame(the_officials)

# %%
officials_df
# Out:
#                        name  \
# 0        Charles E. Schumer
# 1     Kirsten E. Gillibrand
# 2        Nydia M. Velázquez
# 3                Grace Meng
# 4          Yvette D. Clarke
# ...                     ...
# 1661         Ginnie Farrell
# 1662         Thomas C. Hoey
# 1663            Owusu Anane
# 1664     Edward Hyde Clarke
# 1665     Alfredo D. Balarin
#
#                                                 address             party  \
# 0     [{'line1': '322 Hart Senate Office Building', ...  Democratic Party
# 1     [{'line1': '478 Russell Senate Office Building...  Democratic Party
# 2     [{'line1': '2302 Rayburn House Office Building...  Democratic Party
# 3     [{'line1': '2209 Rayburn House Office Building...  Democratic Party
# 4     [{'line1': '2058 Rayburn House Office Building...  Democratic Party
# ...                                                 ...               ...
# 1661  [{'line1': '24 Eagle Street', 'city': 'Albany'...  Democratic Party
# ...
