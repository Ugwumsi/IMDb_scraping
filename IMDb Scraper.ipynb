# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# Call Driver

# %%
#Set up driver to automatically load chrome browser
my_driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
#Get search result page
feature_films = 'https://www.imdb.com/search/title/?title_type=feature&release_date=2000-01-01,2022-09-14&count=100'

#Open search result page
my_driver.get(feature_films)

# %% [markdown]
# Find Movie Titles

# %%
from selenium.webdriver.common.by import By

# %%
#get all header elements

header_ = my_driver.find_elements(By.TAG_NAME,'h3')

#Get movie elemnts with tag_name 'a'
#loops through all elements in 'header_' and gets the titles

title_ = []
title_element = []
for i in header_:
    if i.text == 'Recently Viewed':
        pass
    else:
        
        title_.append(i.find_element(By.TAG_NAME,'a').text)
        title_element.append(i.find_element(By.TAG_NAME,'a').get_attribute('href'))

#Check the first link
#print(title_links[0])

# %%
#Check the first title
title_[0]
# Out:
# 'The Whale'

# %%
titles = my_driver.find_elements(By.TAG_NAME,'h3')
my_feature_titles = []
for title in titles:
    if title.text == 'Recently Viewed':
        pass
    else:
        my_feature_titles.append(title.text)

# %%
my_feature_titles
# Out:
# ['1. The Whale (2022)',
#  '2. Thor: Love and Thunder (2022)',
#  "3. Don't Worry Darling (I) (2022)",
#  '4. Pinocchio (I) (2022)',
#  '5. Elvis (2022)',
#  '6. Top Gun: Maverick (2022)',
#  '7. Nope (2022)',
#  '8. I Came By (2022)',
#  '9. Fall (I) (2022)',
#  '10. Barbarian (2022)',
#  '11. Where the Crawdads Sing (2022)',
#  '12. Bullet Train (2022)',
#  '13. Brahmastra Part One: Shiva (2022)',
#  '14. Glass Onion: A Knives Out Mystery (2022)',
#  '15. Samaritan (2022)',
#  '16. The Lord of the Rings: The Fellowship of the Ring (2001)',
#  '17. Me Time (2022)',
#  '18. Love in the Villa (2022)',
#  '19. Jurassic World Dominion (2022)',
#  '20. Beast (I) (2022)',
#  '21. Blonde (2022)',
#  '22. Everything Everywhere All at Once (2022)',
#  '23. Prey (I) (2022)',
#  '24. X (II) (2022)',
#  '25. Three Thousand Years of Longing (2022)',
#  '26. The Invitation (II) (2022)',
#  '27. After Ever Happy (2022)',
#  '28. This Is 40 (2012)',
#  '29. Orphan: First Kill (2022)',
#  '30. The Black Phone (2021)',
#  '31. See How They Run (2022)',
#  '32. Spider-Man: No Way Home (2021)',
#  '33. Bones and All (2022)',
#  '34. DC League of Super-Pets (2022)',
#  '35. Weird: The Al Yankovic Story (2022)',
#  '36. The Gray Man (2022)',
#  '37. My Son Hunter (2022)',
#  '38. Honk for Jesus. Save Your Soul. (2022)',
#  '39. 365 Days (2020)',
#  '40. Day Shift (2022)',
#  '41. The Batman (2022)',
#  '42. Thirteen Lives (2022)',
#  '43. Loving Adults (2022)',
#  '44. Dune (2021)',
#  '45. Armageddon Time (2022)',
#  '46. The Northman (2022)',
#  '47. The Lord of the Rings: The Return of the King (2003)',
#  '48. Morbius (2022)',
#  '49. Bodies Bodies Bodies (2022)',
#  '50. All Quiet on the Western Front (2022)',
#  '51. Midsommar (2019)',
#  '52. Medieval (2022)',
#  '53. The Lost City (2022)',
#  '54. Look Both Ways (2022)',
#  '55. Once Upon a Time in Hollywood (2019)',
#  '56. Sing 2 (2021)',
#  '57. The Poison Rose (2019)',
#  '58. Licorice Pizza (2021)',
#  '59. Collateral (2004)',
#  '60. End of the Road (II) (2022)',
#  '61. Orphan (2009)',
#  '62. The Lord of the Rings: The Two Towers (2002)',
#  '63. Doctor Strange in the Multiverse of Madness (2022)',
#  '64. Uncharted (2022)',
#  '65. The Banshees of Inisherin (2022)',
#  '66. Cuttputli (2022)',
#  '67. Dragon Ball Super: Super Hero (2022)',
#  '68. The Hobbit: An Unexpected Journey (2012)',
#  '69. Moonfall (2022)',
#  '70. Pearl (2022)',
#  '71. My Policeman (2022)',
#  '72. Minions: The Rise of Gru (2022)',
#  '73. Knives Out (2019)',
#  '74. Avatar (2009)',
#  '75. Lightyear (2022)',
#  '76. Bros (2022)',
#  '77. Death on the Nile (2022)',
#  "78. Harry Potter and the Sorcerer's Stone (2001)",
#  '79. Purple Hearts (2022)',
#  '80. Get Out (I) (2017)',
#  '81. Belfast (2021)',
#  '82. Pleasure (2021)',
#  '83. Interstellar (2014)',
#  '84. Mother! (2017)',
#  '85. RRR (2022)',
#  '86. Ticket to Paradise (2022)',
#  '87. The Woman King (2022)',
#  '88. The Dark Knight (2008)',
#  '89. Hit: The First Case (2022)',
#  '90. One Way (I) (2022)',
#  '91. Crimes of the Future (2022)',
#  '92. Empire of Light (2022)',
#  '93. The Fabelmans (2022)',
#  '94. Wire Room (2022)',
#  '95. House of Gucci (2021)',
#  '96. Marcel the Shell with Shoes On (2021)',
#  '97. Tár (2022)',
#  '98. The Next 365 Days (2022)',
#  '99. No Time to Die (2021)',
#  '100. Vengeance (II) (2022)']

# %%
#Get the links of all the movies

link_parent = my_driver.find_elements(By.TAG_NAME,'h3')
#link_child = link_parent.find_elements(By.TAG_NAME, 'a')
print(len(link_parent))
feature_film_url = []

for i in link_parent:
    #print(i)
    #new_link_parent = my_driver.find_element(By.TAG_NAME,'h3')
    #print(new_link_parent)
    if i.text == 'Recently Viewed':
        pass
    else:
        link_child = i.find_element(By.TAG_NAME, 'a')
        feature_film_url.append(link_child.get_attribute('href'))
# Out:
# 101

# %%
link_parent = my_driver.find_element(By.TAG_NAME,'h3')
link_child = link_parent.find_element(By.TAG_NAME, 'a')
link_child.get_attribute('href')
# Out:
# 'https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt'

# %%
def the_titles():
    my_feature_titles = []
    titles = my_driver.find_elements(By.TAG_NAME,'h3')
    for title in titles:
        if title.text == 'Recently Viewed':
            pass
        else:
            my_feature_titles.append(title.text)
    return my_feature_titles

# %%
#driver.get_element(By.TAG_NAME, 'h3')

# %%
def scrape_data():
    '''Scrapes all the data on any search result page (waits 3 seconds for page to load ). It gets all HTML (parent) elements with the 'h3' tag 
       and stores it in a variable 'header_', then a for-loop that gets the child element with tag 
       name 'a', and appends the text of the result to a list, 'title'. 
       The same is done for a second list 'title_element' which contains the 'href' attribute (link) to every title.
       
       Returns a dictionary with the 'Title' and the 'links'
    ''' 
    
    #Open search result page
    my_driver.get(feature_films)
    
    #get all header elements
    header_ = my_driver.find_elements(By.TAG_NAME,'h3')

    #Initialize empty lists for title and title links
    title_ = []
    title_element = []
    
    #Get movie elemnts with tag_name 'a'
    #loops through all elements in 'header_' and gets the titles
    for i in header_:
        if i.text == 'Recently Viewed':
            pass
        else:
            title = title_.append(i.find_element(By.TAG_NAME,'a').text)
            title_link = title_element.append(title.get_attribute('href'))
            my_driver.get(i)
            
    df = {'Title':title, 'Link':title_link}
    return pd.DataFrame(df)
# Out:
# []

# %%
time.sleep(3)

scrape_data()

page_count = my_driver.find_element(By.XPATH,'//*[@id="main"]/div/div[4]/span[1]').text.split('-')[1].split(' ')[0]
serial_number = my_driver.find_element(By.XPATH,'//*[@id="main"]/div/div[3]/div/div[100]/div[3]/h3/span[1]').text[].strip('.')
if page_count == serial_number:
    my_driver.find_element(By.LINK_TEXT,'Next »').click()
    
    time.wait(5)
    scrape_data()

# %%
# Out:
# [10, 20, 30]

# %%
//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[2]/div/div[1]/a/div/div/div[2]/div[1]/span[1]

//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[2]/div/div[1]/a/div/div/div[2]/div[3]

# %%
my_driver.find_elements(By.CSS_SELECTOR,'h3.lister-item-header > span.lister-item-index.unbold.text-primary')[3].text
# Out:
# '4.'

# %%
my_driver.find_element(By.CSS_SELECTOR, '#main > div > div.desc > a.lister-page-next.next-page').click()

# %%
my_driver.find_element(By.CSS_SELECTOR,'a.lister-page-next.next-page').click()

# %%
#my_driver.find_element(By.XPATH,'//*[@id="main"]/div/div[4]/a[1]').text

# my_driver.find_element(By.LINK_TEXT,'Next »').click()

# my_driver.find_elements(By.TAG_NAME,'h3')[2].text

# my_driver.find_element(By.XPATH,'//*[@id="main"]/div/div[4]/span[1]').text.split(' ')[0].split('-')[1]

# my_driver.find_element(By.CSS_SELECTOR,'h3.lister-item-header > span.lister-item-index.unbold.text-primary').text.strip('.')

# my_driver.find_element(By.CSS_SELECTOR,'h3.lister-item-header > a').get_attribute('href')
my_driver.get(feature_films)



header = my_driver.find_elements(By.CSS_SELECTOR,'h3.lister-item-header')[]
header.find_element(By.CSS_SELECTOR,'span').text

# my_driver.find_elements(By.CSS_SELECTOR,'h3.lister-item-header > a')[int(my_driver.find_elements(By.CSS_SELECTOR,'h3.lister-item-header > span.lister-item-index.unbold.text-primary')[3].text.strip('.'))]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [211], line 17
#      12 my_driver.get(feature_films)
#      16 header = my_driver.find_elements(By.CSS_SELECTOR,'h3.lister-item-header')
# ---> 17 header.find_element(By.CSS_SELECTOR,'span').text
#
# AttributeError: 'list' object has no attribute 'find_element'

# %%
def bitch_nigga(num):
    the_nigga = num%100
    if num == 0:
        return 0
    elif the_nigga == 0:
        return 100
    else:
        return the_nigga
    
#def bitch_nigga(234)

# %%
[bitch_nigga(101)]
# Out:
# [1]

# %%
my_driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2000-01-01,2022-09-14&count=100')

# %%
import time
def scrape_data():
    '''Scrapes all the data on any search result page (waits 3 seconds for page to load ). It gets all HTML (parent) elements with the 'h3' tag 
       and stores it in a variable 'header_', then a for-loop that gets the child element with tag 
       name 'a', and appends the text of the result to a list, 'title'. 
       The same is done for a second list 'title_element' which contains the 'href' attribute (link) to every title.
       
       Returns a dictionary with the 'Title' and the 'links'
    ''' 
    
    #Open search result page
    page_one = my_driver.get(feature_films)
    
    
    #get all header elements
    #header_ = my_driver.find_elements(By.TAG_NAME,'h3')
    
    #Initialize empty lists for title and title links
    global title_
    global title_element
    title_ = []
    title_element = []
    release_date = []
    rating = []
    total_votes = []
    award_nom_wins = []
    country_of_origin = []
    
    def benn_ten(num):
        here = num%100
        if here == 0:
            return 100
        else:
            return here
    #Get movie elemnts with tag_name 'a'
    #loops through all elements in 'header_' and gets the titles
    start = 0
    for i in range(130):
        #my_driver.get(feature_films)
        header = my_driver.find_elements(By.CSS_SELECTOR,'h3.lister-item-header')[bitch_nigga(i)]
        if start == 120:
            break
        else:
            pass
        print('Hello')
        #feature_films = 'https://www.imdb.com/search/title/?title_type=feature&release_date=2000-01-01,2022-09-14&count=100'
        #webdriver.Chrome(service=Service(ChromeDriverManager().install()))
        #my_driver.get(feature_films)
        
        
#         if i.text == 'Recently Viewed':
#             pass
        if header.find_element(By.CSS_SELECTOR,'span').text.strip('.') == my_driver.find_element(By.XPATH,'//*[@id="main"]/div/div[4]/span[1]').text.split(' ')[0].split('-')[1]:
            if my_driver.find_element(By.CSS_SELECTOR,'div.desc > a.lister-page-next.next-page').text not in my_driver.find_element(By.CSS_SELECTOR,'div.desc').text:
                break
            else:
                page_one = my_driver.find_element(By.PARTIAL_LINK_TEXT,'Next')
                page_one.click()
                time.sleep(4)
                #header = my_driver.find_elements(By.CSS_SELECTOR,'h3.lister-item-header > a')
                #title_.append(i.find_element(By.TAG_NAME,'a').text)
                #title_element.append(i.find_element(By.TAG_NAME,'a').get_attribute('href'))
        else:
#             print('before Nums')
#             #nums = header_.find_element(By.CSS_SELECTOR,'h3.lister-item-header > span.lister-item-index.unbold.text-primary').text.strip('.')
#             print('After Nums')
#             page_in = my_driver.find_element(By.XPATH,'//*[@id="main"]/div/div[4]/span[1]').text.split(' ')[0].split('-')[1]
#             print('After Page Index')
#             pg_bottom = my_driver.find_element(By.CSS_SELECTOR,'div.desc').text
#             print('After Page Bottom')
#             next_button = my_driver.find_element(By.CSS_SELECTOR,'div.desc > a.lister-page-next.next-page').text
#             print('After Next Button')
            title_.append(header.find_element(By.CSS_SELECTOR,'a').text)
            title_element.append(header.find_element(By.CSS_SELECTOR,'a').get_attribute('href'))
            #print(title_,title_element)
        print(start)
        start += 1
            
    for url in title_element:

        #feature_films = 'https://www.imdb.com/search/title/?title_type=feature&release_date=2000-01-01,2022-09-14&count=100'
        #webdriver.Chrome(service=Service(ChromeDriverManager().install()))
        my_driver.get(url)

        release = my_driver.find_elements(By.CSS_SELECTOR,'div.sc-f65f65be-0.ktSkVi ul.ipc-inline-list.ipc-inline-list--show-dividers.ipc-inline-list--inline.ipc-metadata-list-item__list-content.base a')
        release_date.append(release[0].text)


        rates = my_driver.find_element(By.CSS_SELECTOR, 'div.ipc-button__text > div.sc-f6306ea-3.loTxjn')
        if rates.text == 'Rate':
            rating.append(None)
        else:
            rating.append(rates.text[:3])



        total_votes.append(rates.text[8:])


        country_of_origin.append(release[1].text)

        wins = my_driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[1]')
        if 'Award' in wins.text:
            award_nom_wins.append(wins.text)
        else:
            award_nom_wins.append(None)

        direct = my_driver.find_elements(By.XPATH, '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/div[3]/ul/li[1]/div')
        directors.append(direct[0].text)
    dick = {'Title':title_, 'Link':title_element, 'Release Date':release_date,
         'Rating':rating, 'Total Votes':total_votes, 'Awards Wins & Nominations':award_nom_wins,
         'Country of Origin':country_of_origin}
    df = pd.DataFrame(dick)
    #df.to_csv('imdb_feature_films.csv', index=False)
    return df

# %%
scrape_data()
# Out:
# Hello
# 0
# Hello
# 1
# Hello
# 2
# Hello
# 3
# Hello
# 4
# Hello
# 5
# Hello
# 6
# Hello
# 7
# Hello
# 8
# Hello
# 9
# Hello
# 10
# Hello
# 11
# Hello
# 12
# Hello
# 13
# Hello
# 14
# Hello
# 15
# Hello
# 16
# Hello
# 17
# Hello
# 18
# Hello
# 19
# Hello
# 20
# Hello
# 21
# Hello
# 22
# Hello
# 23
# Hello
# 24
# Hello
# 25
# Hello
# 26
# Hello
# 27
# Hello
# 28
# Hello
# 29
# Hello
# 30
# Hello
# 31
# Hello
# 32
# Hello
# 33
# Hello
# 34
# Hello
# 35
# Hello
# 36
# Hello
# 37
# Hello
# 38
# Hello
# 39
# Hello
# 40
# Hello
# 41
# Hello
# 42
# Hello
# 43
# Hello
# 44
# Hello
# 45
# Hello
# 46
# Hello
# 47
# Hello
# 48
# Hello
# 49
# Hello
# 50
# Hello
# 51
# Hello
# 52
# Hello
# 53
# Hello
# 54
# Hello
# 55
# Hello
# 56
# Hello
# 57
# Hello
# 58
# Hello
# 59
# Hello
# 60
# Hello
# 61
# Hello
# 62
# Hello
# 63
# Hello
# 64
# Hello
# 65
# Hello
# 66
# Hello
# 67
# Hello
# 68
# Hello
# 69
# Hello
# 70
# Hello
# 71
# Hello
# 72
# Hello
# 73
# Hello
# 74
# Hello
# 75
# Hello
# 76
# Hello
# 77
# Hello
# 78
# Hello
# 79
# Hello
# 80
# Hello
# 81
# Hello
# 82
# Hello
# 83
# Hello
# 84
# Hello
# 85
# Hello
# 86
# Hello
# 87
# Hello
# 88
# Hello
# 89
# Hello
# 90
# Hello
# 91
# Hello
# 92
# Hello
# 93
# Hello
# 94
# Hello
# 95
# Hello
# 96
# Hello
# 97
# Hello
# 98
# Hello
# 99
# Hello
# 100
# Hello
# 101
# Hello
# 102
# Hello
# 103
# Hello
# 104
# Hello
# 105
# Hello
# 106
# Hello
# 107
# Hello
# 108
# Hello
# 109
# Hello
# 110
# Hello
# 111
# Hello
# 112
# Hello
# 113
# Hello
# 114
# Hello
# 115
# Hello
# 116
# Hello
# 117
# Hello
# 118
# Hello
# 119
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [272], line 1
# ----> 1 scrape_data()
#
# Cell In [271], line 86, in scrape_data()
#      83 my_driver.get(url)
#      85 release = my_driver.find_elements(By.CSS_SELECTOR,'div.sc-f65f65be-0.ktSkVi ul.ipc-inline-list.ipc-inline-list--show-dividers.ipc-inline-list--inline.ipc-metadata-list-item__list-content.base a')
# ---> 86 release_date.append(release[0].text)
#      89 rates = my_driver.find_element(By.CSS_SELECTOR, 'div.ipc-button__text > div.sc-f6306ea-3.loTxjn')
#      90 if rates.text == 'Rate':
#
# IndexError: list index out of range

# %%
# my_driver.find_elements(By.CSS_SELECTOR,'div.sc-f65f65be-0.ktSkVi ul.ipc-inline-list.ipc-inline-list--show-dividers.ipc-inline-list--inline.ipc-metadata-list-item__list-content.base a')


import os 
#Set path fro project with variable name 'my_path'
my_path = '/Users/macbookpro2018/data_science/web_scraping'
#set file name with variable name 'my_file'
my_file = 'imdb_feature_films.csv'

# os.path.exists(my_file)

#Check if current working directory is the preferred working directory where we want our file
if os.getcwd() == my_path:
    #If above statement is true, check if our csv file exists.
    if os.path.exists(my_file):
        #If our csv file exists, open the file 
        with open(my_file,'a+') as file:
            #Read the file from the first character.
            file.seek(0)
            
            if file.readline()[-1] == 
            #file.close()
            
        
        
    else:
        with open(my_file, 'a') as file:
            pass
else:
    os.chdir(my_path)
    if os.path.exists(my_file):
        df = pd.read_csv(my_file, keep_default_na=False)
        df.iloc[-1]
        
    else:
        with open(my_file, 'w') as file:
            pass

pd.DataFrame.to_csv()
# Out:
# 0
# Ti

# %%
pd.read_csv(my_file)
# Out:
#                     Title                                               Link  \
# 0               The Whale  https://www.imdb.com/title/tt13833688/?ref_=ad...
# 1  Thor: Love and Thunder  https://www.imdb.com/title/tt10648342/?ref_=ad...
# 2     Don't Worry Darling  https://www.imdb.com/title/tt10731256/?ref_=ad...
#
#                          Release Date  Rating Total Votes  \
# 0    December 9, 2022 (United States)     NaN         NaN
# 1        July 8, 2022 (United States)     6.5        243K
# 2  September 23, 2022 (United States)     NaN         NaN
#
#       Awards Wins & Nominations Country of Origin
# 0  Awards4 wins & 2 nominations     United States
# 1           Awards3 nominations         Australia
# 2   Awards1 win & 2 nominations     United States

# %%
# my_file in os.walk(my_path)
print(os.getcwd())
os.path.exists(my_file)
# Out:
# /Users/macbookpro2018/data_science/web_scraping
# True

# %%
os.chdir('/Users/macbookpro2018/data_science/web_scraping')
print(os.getcwd())
# Out:
# /Users/macbookpro2018/data_science/web_scraping

# %%
df = pd.read_csv(my_file, keep_default_na=False)
df.iloc[-1]
# Out:
# Title                                                      Don't Worry Darling
# Link                         https://www.imdb.com/title/tt10731256/?ref_=ad...
# Release Date                                September 23, 2022 (United States)
# Rating
# Total Votes
# Awards Wins & Nominations                        Awards\n1 win & 2 nominations
# Country of Origin                                                United States
# Name: 2, dtype: object

# %%
#my_driver.get(feature_films)
my_driver.find_element(By.XPATH,'//*[@id="main"]/div/div[4]/span[1]').text.split(' ')[0].split('-')[1]
# Out:
# '100'

# %%
my_driver.find_element(By.XPATH, '//*[@id="main"]/div/div[3]/div/div[100]/div[3]/h3/span[1]').text.strip('.')
# Out:
# '100'

# %%
my_driver.find_element(By.CSS_SELECTOR,'div.sc-f6306ea-3.loTxjn').text
# Out:
# 'Rate'

# %%
#my_driver.get(feature_films)

my_driver.find_elements(By.XPATH, '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/div[3]/ul/li[1]/div').text
# Out:
# 'Peter Jackson'

# %%
release_date = []
rating = []
total_votes = []
award_nom_wins = []
country_of_origin = []
directors = []

start = 0

for url in title_element:
    
    if start == 10:
        break
    else:
    
        #feature_films = 'https://www.imdb.com/search/title/?title_type=feature&release_date=2000-01-01,2022-09-14&count=100'
        #webdriver.Chrome(service=Service(ChromeDriverManager().install()))
        my_driver.get(url)
        
        release = my_driver.find_elements(By.CSS_SELECTOR,'div.sc-f65f65be-0.ktSkVi ul.ipc-inline-list.ipc-inline-list--show-dividers.ipc-inline-list--inline.ipc-metadata-list-item__list-content.base a')
        release_date.append(release[0].text)

        
        rates = my_driver.find_element(By.CSS_SELECTOR, 'div.ipc-button__text > div.sc-f6306ea-3.loTxjn')
        if rates.text == 'Rate':
            rating.append(None)
        else:
            rating.append(rates.text[:3])
        

        
        total_votes.append(rates.text[8:])


        country_of_origin.append(release[1].text)

        wins = my_driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[1]')
        if 'Award' in wins.text:
            award_nom_wins.append(wins.text)
        else:
            award_nom_wins.append(None)
        
        direct = my_driver.find_elements(By.XPATH, '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/div[3]/ul/li[1]/div')
        directors.append(direct[0].text)
        
    start += 1
#     df = {'Title':title_, 'Link':title_element, 'Release Date':release_date,
#          'Rating':rating, 'Total Votes':total_votes, 'Awards Wins & Nominations':award_nom_wins,
#          'Country of Origin':country_of_origin}
#     print(df)
    #time.sleep(4)
    #my_driver.get(feature_films)

# %%
import pandas as pd
# print('Release Date: ', release_date)
# print('Rating: ', rating)
# print('Total Votes: ', total_votes)
# print('Award Wins: ', award_nom_wins)
# print('Country: ', country_of_origin)
# print('Directors: ', directors)

#df = {'Release Date':release_date,'Rating': rating,'Total Votes': total_votes,'Award Wins': award_nom_wins,
#     'Country': country_of_origin,'Directors': directors}

df1 = pd.DataFrame(list(zip(release_date,rating,total_votes,award_nom_wins,country_of_origin,directors)),
                   columns=['Release Date','Rating','Total Votes','Award Wins','Country','Directors'])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Release Date  10 non-null     object
#  1   Rating        8 non-null      object
#  2   Total Votes   10 non-null     object
#  3   Award Wins    6 non-null      object
#  4   Country       10 non-null     object
#  5   Directors     10 non-null     object
# dtypes: object(6)
# memory usage: 608.0+ bytes

# %%
scrape_data()
# Out:
# Hello
# ['The Whale'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling"] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing', 'The Invitation'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12873562/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing', 'The Invitation', 'After Ever Happy'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12873562/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13070038/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing', 'The Invitation', 'After Ever Happy', 'This Is 40'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12873562/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13070038/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1758830/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing', 'The Invitation', 'After Ever Happy', 'This Is 40', 'Orphan: First Kill'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12873562/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13070038/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1758830/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11851548/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing', 'The Invitation', 'After Ever Happy', 'This Is 40', 'Orphan: First Kill', 'The Black Phone'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12873562/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13070038/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1758830/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11851548/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt7144666/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing', 'The Invitation', 'After Ever Happy', 'This Is 40', 'Orphan: First Kill', 'The Black Phone', 'See How They Run'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12873562/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13070038/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1758830/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11851548/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt7144666/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13640696/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing', 'The Invitation', 'After Ever Happy', 'This Is 40', 'Orphan: First Kill', 'The Black Phone', 'See How They Run', 'Spider-Man: No Way Home'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12873562/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13070038/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1758830/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11851548/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt7144666/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13640696/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10872600/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing', 'The Invitation', 'After Ever Happy', 'This Is 40', 'Orphan: First Kill', 'The Black Phone', 'See How They Run', 'Spider-Man: No Way Home', 'Bones and All'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12873562/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13070038/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1758830/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11851548/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt7144666/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13640696/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10872600/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10168670/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing', 'The Invitation', 'After Ever Happy', 'This Is 40', 'Orphan: First Kill', 'The Black Phone', 'See How They Run', 'Spider-Man: No Way Home', 'Bones and All', 'DC League of Super-Pets'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12873562/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13070038/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1758830/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11851548/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt7144666/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13640696/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10872600/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10168670/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8912936/?ref_=adv_li_tt']
# Bye, Mutherfucker!!!
# Hello
# ...
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing', 'The Invitation', 'After Ever Happy', 'This Is 40', 'Orphan: First Kill', 'The Black Phone', 'See How They Run', 'Spider-Man: No Way Home', 'Bones and All', 'DC League of Super-Pets', 'Weird: The Al Yankovic Story', 'The Gray Man', 'My Son Hunter', 'Honk for Jesus. Save Your Soul.', '365 Days', 'Day Shift', 'The Batman', 'Thirteen Lives', 'Loving Adults', 'Dune', 'Armageddon Time', 'The Northman', 'The Lord of the Rings: The Return of the King', 'Morbius', 'Bodies Bodies Bodies', 'All Quiet on the Western Front', 'Midsommar', 'Medieval', 'The Lost City', 'Look Both Ways', 'Once Upon a Time in Hollywood', 'Sing 2', 'The Poison Rose', 'Licorice Pizza', 'Collateral', 'End of the Road', 'Orphan', 'The Lord of the Rings: The Two Towers', 'Doctor Strange in the Multiverse of Madness', 'Uncharted', 'The Banshees of Inisherin', 'Cuttputli', 'Dragon Ball Super: Super Hero', 'The Hobbit: An Unexpected Journey', 'Moonfall', 'Pearl', 'My Policeman', 'Minions: The Rise of Gru', 'Knives Out', 'Avatar', 'Lightyear', 'Bros', 'Death on the Nile', "Harry Potter and the Sorcerer's Stone", 'Purple Hearts', 'Get Out', 'Belfast', 'Pleasure', 'Interstellar', 'Mother!', 'RRR', 'Ticket to Paradise', 'The Woman King', 'The Dark Knight', 'Hit: The First Case', 'One Way', 'Crimes of the Future', 'Empire of Light', 'The Fabelmans', 'Wire Room', 'House of Gucci', 'Marcel the Shell with Shoes On', 'Tár', 'The Next 365 Days'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12873562/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13070038/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1758830/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11851548/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt7144666/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13640696/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10872600/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10168670/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8912936/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt17076046/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1649418/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15481952/?ref_=adv_li_tt',  ...
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing', 'The Invitation', 'After Ever Happy', 'This Is 40', 'Orphan: First Kill', 'The Black Phone', 'See How They Run', 'Spider-Man: No Way Home', 'Bones and All', 'DC League of Super-Pets', 'Weird: The Al Yankovic Story', 'The Gray Man', 'My Son Hunter', 'Honk for Jesus. Save Your Soul.', '365 Days', 'Day Shift', 'The Batman', 'Thirteen Lives', 'Loving Adults', 'Dune', 'Armageddon Time', 'The Northman', 'The Lord of the Rings: The Return of the King', 'Morbius', 'Bodies Bodies Bodies', 'All Quiet on the Western Front', 'Midsommar', 'Medieval', 'The Lost City', 'Look Both Ways', 'Once Upon a Time in Hollywood', 'Sing 2', 'The Poison Rose', 'Licorice Pizza', 'Collateral', 'End of the Road', 'Orphan', 'The Lord of the Rings: The Two Towers', 'Doctor Strange in the Multiverse of Madness', 'Uncharted', 'The Banshees of Inisherin', 'Cuttputli', 'Dragon Ball Super: Super Hero', 'The Hobbit: An Unexpected Journey', 'Moonfall', 'Pearl', 'My Policeman', 'Minions: The Rise of Gru', 'Knives Out', 'Avatar', 'Lightyear', 'Bros', 'Death on the Nile', "Harry Potter and the Sorcerer's Stone", 'Purple Hearts', 'Get Out', 'Belfast', 'Pleasure', 'Interstellar', 'Mother!', 'RRR', 'Ticket to Paradise', 'The Woman King', 'The Dark Knight', 'Hit: The First Case', 'One Way', 'Crimes of the Future', 'Empire of Light', 'The Fabelmans', 'Wire Room', 'House of Gucci', 'Marcel the Shell with Shoes On', 'Tár', 'The Next 365 Days', 'No Time to Die'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12873562/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13070038/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1758830/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11851548/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt7144666/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13640696/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10872600/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10168670/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8912936/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt17076046/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1649418/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15481952/ ...
# Bye, Mutherfucker!!!
# Hello
# ['The Whale', 'Thor: Love and Thunder', "Don't Worry Darling", 'Pinocchio', 'Elvis', 'Top Gun: Maverick', 'Nope', 'I Came By', 'Fall', 'Barbarian', 'Where the Crawdads Sing', 'Bullet Train', 'Brahmastra Part One: Shiva', 'Glass Onion: A Knives Out Mystery', 'Samaritan', 'The Lord of the Rings: The Fellowship of the Ring', 'Me Time', 'Love in the Villa', 'Jurassic World Dominion', 'Beast', 'Blonde', 'Everything Everywhere All at Once', 'Prey', 'X', 'Three Thousand Years of Longing', 'The Invitation', 'After Ever Happy', 'This Is 40', 'Orphan: First Kill', 'The Black Phone', 'See How They Run', 'Spider-Man: No Way Home', 'Bones and All', 'DC League of Super-Pets', 'Weird: The Al Yankovic Story', 'The Gray Man', 'My Son Hunter', 'Honk for Jesus. Save Your Soul.', '365 Days', 'Day Shift', 'The Batman', 'Thirteen Lives', 'Loving Adults', 'Dune', 'Armageddon Time', 'The Northman', 'The Lord of the Rings: The Return of the King', 'Morbius', 'Bodies Bodies Bodies', 'All Quiet on the Western Front', 'Midsommar', 'Medieval', 'The Lost City', 'Look Both Ways', 'Once Upon a Time in Hollywood', 'Sing 2', 'The Poison Rose', 'Licorice Pizza', 'Collateral', 'End of the Road', 'Orphan', 'The Lord of the Rings: The Two Towers', 'Doctor Strange in the Multiverse of Madness', 'Uncharted', 'The Banshees of Inisherin', 'Cuttputli', 'Dragon Ball Super: Super Hero', 'The Hobbit: An Unexpected Journey', 'Moonfall', 'Pearl', 'My Policeman', 'Minions: The Rise of Gru', 'Knives Out', 'Avatar', 'Lightyear', 'Bros', 'Death on the Nile', "Harry Potter and the Sorcerer's Stone", 'Purple Hearts', 'Get Out', 'Belfast', 'Pleasure', 'Interstellar', 'Mother!', 'RRR', 'Ticket to Paradise', 'The Woman King', 'The Dark Knight', 'Hit: The First Case', 'One Way', 'Crimes of the Future', 'Empire of Light', 'The Fabelmans', 'Wire Room', 'House of Gucci', 'Marcel the Shell with Shoes On', 'Tár', 'The Next 365 Days', 'No Time to Die', 'Vengeance'] ['https://www.imdb.com/title/tt13833688/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10648342/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10731256/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt4593060/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt3704428/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1745960/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10954984/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15083184/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15325794/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15791034/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9411972/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12593682/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6277462/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11564570/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt5500218/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt0120737/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt14309446/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt15463032/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8041270/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13223398/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1655389/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt6710474/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11866324/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13560574/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt9198364/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt12873562/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13070038/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1758830/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt11851548/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt7144666/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt13640696/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10872600/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt10168670/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt8912936/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt17076046/?ref_=adv_li_tt', 'https://www.imdb.com/title/tt1649418/?ref_=adv_li_tt', 'https://www.imdb.com/titl ...
# Bye, Mutherfucker!!!
# Hello
# Bye, Mutherfucker!!!

# %%
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions

# %%
WebDriverWait()

# %% [markdown]
# # Main Code Starts Here

# %%
import os 
import time

def scrape_data():
    '''Scrapes all the data on any search result page (waits 3 seconds for page to load ). It gets all HTML (parent) elements with the 'h3' tag 
       and stores it in a variable 'header_', then a for-loop that gets the child element with tag 
       name 'a', and appends the text of the result to a list, 'title'. 
       The same is done for a second list 'title_element' which contains the 'href' attribute (link) to every title.
       
       Returns a dictionary with the 'Title' and the 'links'
    ''' 
    
    #Open search result page
    page_one = my_driver.get(feature_films)
    
    
    #get all header elements
    #header_ = my_driver.find_elements(By.TAG_NAME,'h3')
    
    #Initialize empty lists for title and title links
    global title_
    global title_element
    global release_date
    global rating
    global total_votes
    global award_nom_wins
    global country_of_origin
    title_ = []
    title_element = []
    release_date = []
    rating = []
    total_votes = []
    award_nom_wins = []
    country_of_origin = []
    
    def bitch_nigga(num):
    the_nigga = num%100
    if num == 0:
        return 0
    elif the_nigga == 0:
        return 100
    else:
        return the_nigga
    #Get movie elemnts with tag_name 'a'
    #loops through all elements in 'header_' and gets the titles
    start = 0
    for i in range(130):
        #my_driver.get(feature_films)
        header = my_driver.find_elements(By.CSS_SELECTOR,'h3.lister-item-header')[bitch_nigga(i)]
        if start == 120:
            break
        else:
            pass
        print('Hello')
        #feature_films = 'https://www.imdb.com/search/title/?title_type=feature&release_date=2000-01-01,2022-09-14&count=100'
        #webdriver.Chrome(service=Service(ChromeDriverManager().install()))
        #my_driver.get(feature_films)
        
        
#         if i.text == 'Recently Viewed':
#             pass
        if header.find_element(By.CSS_SELECTOR,'span').text.strip('.') == my_driver.find_element(By.XPATH,'//*[@id="main"]/div/div[4]/span[1]').text.split(' ')[0].split('-')[1]:
            if my_driver.find_element(By.CSS_SELECTOR,'div.desc > a.lister-page-next.next-page').text not in my_driver.find_element(By.CSS_SELECTOR,'div.desc').text:
                break
            else:
                page_one = my_driver.find_element(By.PARTIAL_LINK_TEXT,'Next')
                page_one.click()
                time.sleep(4)
                #header = my_driver.find_elements(By.CSS_SELECTOR,'h3.lister-item-header > a')
                #title_.append(i.find_element(By.TAG_NAME,'a').text)
                #title_element.append(i.find_element(By.TAG_NAME,'a').get_attribute('href'))
        else:
#             print('before Nums')
#             #nums = header_.find_element(By.CSS_SELECTOR,'h3.lister-item-header > span.lister-item-index.unbold.text-primary').text.strip('.')
#             print('After Nums')
#             page_in = my_driver.find_element(By.XPATH,'//*[@id="main"]/div/div[4]/span[1]').text.split(' ')[0].split('-')[1]
#             print('After Page Index')
#             pg_bottom = my_driver.find_element(By.CSS_SELECTOR,'div.desc').text
#             print('After Page Bottom')
#             next_button = my_driver.find_element(By.CSS_SELECTOR,'div.desc > a.lister-page-next.next-page').text
#             print('After Next Button')
            title_.append(header.find_element(By.CSS_SELECTOR,'a').text)
            title_element.append(header.find_element(By.CSS_SELECTOR,'a').get_attribute('href'))
            #print(title_,title_element)
        print(start)
        start += 1
            
    for url in title_element:

        #feature_films = 'https://www.imdb.com/search/title/?title_type=feature&release_date=2000-01-01,2022-09-14&count=100'
        #webdriver.Chrome(service=Service(ChromeDriverManager().install()))
        my_driver.get(url)
        
        #Get release date for every movie
        release = my_driver.find_elements(By.CSS_SELECTOR,'div.sc-f65f65be-0.ktSkVi ul.ipc-inline-list.ipc-inline-list--show-dividers.ipc-inline-list--inline.ipc-metadata-list-item__list-content.base a')
        #Appends the release date to the list above
        release_date.append(release[0].text)

        #Get the ratings
        rates = my_driver.find_element(By.CSS_SELECTOR, 'div.ipc-button__text > div.sc-f6306ea-3.loTxjn')
        if rates.text == 'Rate':
            #Appends NONE to the Rating list above
            rating.append(None)
        else:
            #Appends the rates to the rating list above
            rating.append(rates.text[:3])


        #Get Total Votes for movies that have ratings
        total_votes.append(rates.text[8:])

        #Get COuntry of Origin (Country where the movie was made in)
        country_of_origin.append(release[1].text)

        #Get award wins and Nominations
        wins = my_driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[1]')
        if 'Award' in wins.text:
            #Appends the number of wins and awards to the 'award_nom_wins' list above
            award_nom_wins.append(wins.text)
        else:
            #Appends NONE to the 'award_nom_wins' list above
            award_nom_wins.append(None)

        #Get the director of each movie
        direct = my_driver.find_elements(By.XPATH, '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/div[3]/ul/li[1]/div')
        #Appends the directors to the 'Directors' list above
        directors.append(direct[0].text)
        dick = {'Title':title_, 'Link':title_element, 'Release Date':release_date,
             'Rating':rating, 'Total Votes':total_votes, 'Awards Wins & Nominations':award_nom_wins,
             'Country of Origin':country_of_origin}
        df = pd.DataFrame(dick)
    #df.to_csv('imdb_feature_films.csv', index=False)
        return df

#Run the Scrape Data function
scrape_data()


my_path = '/Users/macbookpro2018/data_science/web_scraping'
my_file = 'imdb_feature_films.csv'


if os.getcwd() == my_path:
    if os.path.exists(my_file):
        with open(my_file, 'a+') as file:
            file_df = pd.read_csv(my_file, keep_default_na=False)
            for i in df["Link"]:
                if i in file_df['Link']:
                    pass
                else:
                    os.SEEK_END()
                    file.write('\n')
                    file.write(df.loc[df['Link'] == i])
                    file.close()
        
    else:
        df.to_csv('imdb_feature_films.csv')
else:
    os.chdir(my_path)
    if os.path.exists(my_file):
        with open(my_file, 'a+') as file:
            file_df = pd.read_csv(my_file, keep_default_na=False)
            for i in df['Link']:
                if i in file_df['Link']:
                    pass
                else:
                    os.SEEK_END()
                    file.write('\n')
                    file.write(df.loc[df['Link'] == i])
                    file.close()
    else:
        df.to_csv('imdb_feature_films.csv')

        

#Close the file
#Move the Dictionary, dataFrame and Return keyword back
#Place the cursor on the last line
# Out:
#   Cell In [1], line 139
#     if file_df.iloc[-1]['Link'] == i['Link']
#                                             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

ly_list = {'First':['Nonso','Ugwumsi','Nene'],'Seconnd':['Emmanuel','Chiamaka','Tochukwu']}

df = pd.DataFrame(ly_list)

# %%
df.loc[df['First'] == 'Nonso']
# Out:
#    First   Seconnd
# 0  Nonso  Emmanuel
